# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings('ignore')
import logging
logging.getLogger('matplotlib.mathtext').setLevel(logging.WARNING)

import matplotlib.pyplot as plt

from sbbts_uni_fft import *
from utils.data_generation import *
from utils.eval_functions import *

# %%
M = 100
N = 24
Generator_garch = Generate_Data(M)
X_garch = Generator_garch.generate_GARCH(N=N)

N_pi = 100
deltati = 1/252
grid = np.linspace(-3, 3, 1000)

X_garch_sbts = simusbbts(N=N, M=M, X=X_garch, N_pi=N_pi, h=.2,
                         deltati=deltati, grid=grid, K=100, beta=2, M_simu=1)
# Out:
# Start time: 09:22:54
# Expected finish time: 09:22:54
# Finish time: 09:22:55
# Time to generate 1 samples with N_pi=100: 1 seconds.

# %%
X_garch_sbts
# Out:
# array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]])

# %%
plot_sample(X_garch, X_garch)
